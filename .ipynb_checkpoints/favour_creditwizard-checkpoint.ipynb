# %% [markdown]
# ### Project Title
#
# #### AI-Powered Loan Default Predictor- Creditwiz

# %% [markdown]
# ### Objective
#
#
# To build an AI-driven system that predicts the likelihood of loan default using borrower profiles and financial behavior data. This will enable fintechs and microfinance institutions to make data-informed lending decisions.

# %% [markdown]
# ### Problem Statement
#
# Loan default is a major risk in digital lending, especially in emerging markets like Nigeria where credit history may be sparse. A predictive system using behavioral and transactional data can improve risk assessment beyond traditional credit scoring methods.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_selection import SelectKBest, mutual_info_classif
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder, StandardScaler, OneHotEncoder, RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from imblearn.over_sampling import SMOTE
from collections import Counter
from sklearn.impute import SimpleImputer
from xgboost import XGBClassifier
from sklearn.ensemble import (
    RandomForestClassifier,
    GradientBoostingClassifier,
    AdaBoostClassifier,
    ExtraTreesClassifier
)
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, precision_recall_curve, average_precision_score

from scipy import stats

import joblib
import warnings
warnings.filterwarnings('ignore')

# %%
# Show all columns in outputs
pd.set_option('display.max_columns', None)

#  Optional: Show all rows (be careful with huge datasets)
# pd.set_option('display.max_rows', None)

# %%
# Reading compressed Lending Club file
# df = pd.read_csv("data/accepted_2007_to_2018Q4.csv.gz", compression='gzip')

# Sampling 100000 rows from the dataset
# df = df.sample(n=100000, random_state=42)

# %%
df = pd.read_csv("data/sampled_lending_data.csv")
df.head()
# Out:
#           id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0   39651438        NaN    32000.0      32000.0          32000.0   60 months
# 1   16411620        NaN     9600.0       9600.0           9600.0   36 months
# 2   45122316        NaN     4000.0       4000.0           4000.0   36 months
# 3  125356772        NaN     6025.0       6025.0           6025.0   36 months
# 4  128490686        NaN    25000.0      25000.0          25000.0   60 months
#
#    int_rate  installment grade sub_grade        emp_title emp_length  \
# 0     10.49       687.65     B        B3   Public Service  10+ years
# 1     12.99       323.42     C        C1              NaN        NaN
# 2      6.68       122.93     A        A3   System Analyst    4 years
# 3     10.91       197.00     B        B4  Admin assistant  10+ years
# 4     26.30       752.96     E        E5     Coordinator   10+ years
#
#   home_ownership  annual_inc verification_status   issue_d loan_status  \
# ...

# %%
df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 151 columns):
#  #    Column                                      Dtype
# ---   ------                                      -----
#  0    id                                          object
#  1    member_id                                   float64
#  2    loan_amnt                                   float64
#  3    funded_amnt                                 float64
#  4    funded_amnt_inv                             float64
#  5    term                                        object
#  6    int_rate                                    float64
#  7    installment                                 float64
#  8    grade                                       object
#  9    sub_grade                                   object
#  10   emp_title                                   object
#  11   emp_length                                  object
# ...

# %%
df.loan_status.unique()
# Out:
# array(['Current', 'Fully Paid', 'Charged Off', 'Late (31-120 days)',
#        'Late (16-30 days)', 'In Grace Period',
#        'Does not meet the credit policy. Status:Fully Paid',
#        'Does not meet the credit policy. Status:Charged Off', nan],
#       dtype=object)

# %%
df = df[df['loan_status'].isin(['Fully Paid', 'Charged Off'])]
df['loan_status'] = df['loan_status'].map({'Fully Paid': 0, 'Charged Off': 1})

# %%
df.shape
# Out:
# (59494, 151)

# %%
# Relevant raw features + target
cols = [
    # Loan
    'loan_amnt', 'term', 'int_rate', 'installment', 'purpose', 'grade',
    # Borrower
    'annual_inc', 'emp_length', 'home_ownership', 'verification_status',
    # Credit
    'dti', 'open_acc', 'total_acc', 'inq_last_6mths',
    'revol_util', 'delinq_2yrs', 'pub_rec', 'revol_bal',
    # Target
    'loan_status'
]

df = df[cols].copy()
print(df.shape)
print(df.isnull().sum())
# Out:
# (59494, 19)
# loan_amnt                 0
# term                      0
# int_rate                  0
# installment               0
# purpose                   0
# grade                     0
# annual_inc                0
# emp_length             3470
# home_ownership            0
# verification_status       0
# dti                      20
# open_acc                  0
# total_acc                 0
# inq_last_6mths            0
# revol_util               32
# delinq_2yrs               0
# pub_rec                   0
# revol_bal                 0
# loan_status               0
# dtype: int64

# %%
df.head()
# Out:
#    loan_amnt        term  int_rate  installment             purpose grade  \
# 1     9600.0   36 months     12.99       323.42  debt_consolidation     C
# 2     4000.0   36 months      6.68       122.93      major_purchase     A
# 3     6025.0   36 months     10.91       197.00  debt_consolidation     B
# 5    20000.0   36 months      9.49       640.57  debt_consolidation     B
# 6     1000.0   36 months      8.18        31.42  debt_consolidation     B
#
#    annual_inc emp_length home_ownership verification_status    dti  open_acc  \
# 1     21900.0        NaN           RENT            Verified  10.03      13.0
# 2     83000.0    4 years       MORTGAGE        Not Verified  19.53      16.0
# 3     52000.0  10+ years           RENT        Not Verified   9.16      11.0
# 5    100000.0  10+ years       MORTGAGE        Not Verified  16.43      15.0
# 6     23000.0        NaN           RENT            Verified  16.34       6.0
#
# ...

# %%
df.columns
# Out:
# Index(['loan_amnt', 'term', 'int_rate', 'installment', 'purpose', 'grade',
#        'annual_inc', 'emp_length', 'home_ownership', 'verification_status',
#        'dti', 'open_acc', 'total_acc', 'inq_last_6mths', 'revol_util',
#        'delinq_2yrs', 'pub_rec', 'revol_bal', 'loan_status'],
#       dtype='object')

# %% [markdown]
# ### HANDLING MISSING VALUES

# %%
# HANDLING MISSING VALUES

df['emp_length'] = df['emp_length'].fillna(df['emp_length'].mode()[0])

df['dti'] = df['dti'].fillna(df['dti'].median())

df['revol_util'] = df['revol_util'].fillna(df['revol_util'].median())

print(df.isnull().sum().sum())
print(df.shape)
# Out:
# 0
# (59494, 19)

# %% [markdown]
# ### FEATURES ENGINEERING

# %%
# term: remove " months" and convert to int
df['term'] = df['term'].str.strip().str.replace(' months', '').astype(int)

# emp_length: convert to numeric
emp_map = {
    '< 1 year': 0, '1 year': 1, '2 years': 2, '3 years': 3,
    '4 years': 4, '5 years': 5, '6 years': 6, '7 years': 7,
    '8 years': 8, '9 years': 9, '10+ years': 10
}
df['emp_length'] = df['emp_length'].map(emp_map)

print(df.dtypes)
print(df[['term', 'emp_length']].head())
# Out:
# loan_amnt              float64
# term                     int32
# int_rate               float64
# installment            float64
# purpose                 object
# grade                   object
# annual_inc             float64
# emp_length               int64
# home_ownership          object
# verification_status     object
# dti                    float64
# open_acc               float64
# total_acc              float64
# inq_last_6mths         float64
# revol_util             float64
# delinq_2yrs            float64
# pub_rec                float64
# revol_bal              float64
# loan_status              int64
# dtype: object
#    term  emp_length
# 1    36          10
# 2    36           4
# 3    36          10
# 5    36          10
# 6    36          10

# %%
# Grade encodinG
grade_map = {'A': 1, 'B': 2, 'C': 3, 'D': 4, 'E': 5, 'F': 6, 'G': 7}
df['grade_numeric'] = df['grade'].map(grade_map)
df['high_risk_grade'] = (df['grade_numeric'] >= 5).astype(int)

# DTI flags
df['high_dti_flag'] = (df['dti'] > 30).astype(int)

# Income derived
df['loan_to_monthly_income'] = df['loan_amnt'] / (df['annual_inc'] / 12)
df['debt_to_income_ratio'] = df['dti'] / 100

# Credit inquiry pressure
df['inquiry_pressure'] = df['inq_last_6mths'] / (df['open_acc'] + 1)

# Employment stability
df['stable_employment'] = (df['emp_length'] >= 2).astype(int)
df['very_stable_employment'] = (df['emp_length'] >= 5).astype(int)

# Utilization flags
df['high_utilization'] = (df['revol_util'] > 75).astype(int)
df['very_high_utilization'] = (df['revol_util'] > 90).astype(int)

# Loan flags
df['large_loan_flag'] = (df['loan_amnt'] > 20000).astype(int)
df['long_term_loan'] = (df['term'] == 60).astype(int)

# Account diversity
df['account_diversity'] = df['open_acc'] / (df['total_acc'] + 1)

# Verification strength
verification_map = {'Not Verified': 0, 'Source Verified': 1, 'Verified': 2}
df['verification_strength'] = df['verification_status'].map(verification_map)
df['strong_verification'] = (df['verification_strength'] == 2).astype(int)

# Purpose risk score
purpose_risk_map = {
    'credit_card': 0.2, 'car': 0.2, 'home_improvement': 0.2,
    'major_purchase': 0.3, 'medical': 0.3, 'wedding': 0.3,
    'vacation': 0.4, 'moving': 0.4, 'house': 0.4,
    'debt_consolidation': 0.5, 'other': 0.5,
    'small_business': 0.7, 'renewable_energy': 0.5,
    'educational': 0.4
}
df['purpose_risk_score'] = df['purpose'].map(purpose_risk_map).fillna(0.5)
df['high_risk_purpose'] = (df['purpose_risk_score'] >= 0.5).astype(int)

print(df.shape)
print(df.isnull().sum().sum())
# Out:
# (59494, 36)
# 0

# %%
print(df.columns.tolist())
print(df.dtypes)
# Out:
# ['loan_amnt', 'term', 'int_rate', 'installment', 'purpose', 'grade', 'annual_inc', 'emp_length', 'home_ownership', 'verification_status', 'dti', 'open_acc', 'total_acc', 'inq_last_6mths', 'revol_util', 'delinq_2yrs', 'pub_rec', 'revol_bal', 'loan_status', 'grade_numeric', 'high_risk_grade', 'high_dti_flag', 'loan_to_monthly_income', 'debt_to_income_ratio', 'inquiry_pressure', 'stable_employment', 'very_stable_employment', 'high_utilization', 'very_high_utilization', 'large_loan_flag', 'long_term_loan', 'account_diversity', 'verification_strength', 'strong_verification', 'purpose_risk_score', 'high_risk_purpose']
# loan_amnt                 float64
# term                        int32
# int_rate                  float64
# installment               float64
# purpose                    object
# grade                      object
# annual_inc                float64
# emp_length                  int64
# home_ownership             object
# verification_status        object
# ...

# %%
# Splitting the dataset into features and target.
X = df.drop(columns=['loan_status'])
y = df['loan_status']

print(X.shape)
print(X.columns.tolist())
# Out:
# (59494, 35)
# ['loan_amnt', 'term', 'int_rate', 'installment', 'purpose', 'grade', 'annual_inc', 'emp_length', 'home_ownership', 'verification_status', 'dti', 'open_acc', 'total_acc', 'inq_last_6mths', 'revol_util', 'delinq_2yrs', 'pub_rec', 'revol_bal', 'grade_numeric', 'high_risk_grade', 'high_dti_flag', 'loan_to_monthly_income', 'debt_to_income_ratio', 'inquiry_pressure', 'stable_employment', 'very_stable_employment', 'high_utilization', 'very_high_utilization', 'large_loan_flag', 'long_term_loan', 'account_diversity', 'verification_strength', 'strong_verification', 'purpose_risk_score', 'high_risk_purpose']

# %% [markdown]
# ## EDA

# %%
X_eda = X.copy()
X_eda = X_eda.replace([np.inf, -np.inf], np.nan)
X_eda['loan_status'] = y

# %%
# 1. Class Count
sns.countplot(data=X_eda, x="loan_status")

plt.xticks(ticks=[0, 1], labels=["Fully Paid", "Charged Off"])
plt.xlabel("Loan Status")
plt.show()

print(X_eda['loan_status'].value_counts(normalize=True) * 100)
# Out:
# 0    79.77275
# 1    20.22725
# Name: loan_status, dtype: float64

# %% [markdown]
# #### Target Distribution (Loan Status)
# The dataset is heavily imbalanced with approximately 80% of loans fully paid and 20% charged off.

# %%
# 2. Default rate by grade
grade_default = X_eda.groupby('grade')['loan_status'].mean().reset_index()
grade_default.columns = ['grade', 'default_rate']
grade_order = ['A','B','C','D','E','F','G']
grade_default['grade'] = pd.Categorical(grade_default['grade'], categories=grade_order, ordered=True)
grade_default = grade_default.sort_values('grade')

fig, ax = plt.subplots(figsize=(8, 4))
sns.barplot(data=grade_default, x='grade', y='default_rate', palette='coolwarm', ax=ax)
ax.set_title('Default Rate by Grade')
ax.set_ylabel('Default Rate')
ax.set_xlabel('Grade')
for bar, val in zip(ax.patches, grade_default['default_rate']):
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.005,
            f'{val:.1%}', ha='center', fontsize=9)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Default Rate by Grade
# Credit grade shows a strong monotonic relationship with default risk. Grade A borrowers default at just 6.3% while Grade G reaches 52.7%. This is an 8x spread across the spectrum. This suggests grade is a highly discriminative feature worth retaining in any predictive model.

# %%
# 3. Default rate by purpose
purpose_default = X_eda.groupby('purpose')['loan_status'].mean().sort_values(ascending=False).reset_index()
purpose_default.columns = ['purpose', 'default_rate']

fig, ax = plt.subplots(figsize=(10, 4))
sns.barplot(data=purpose_default, x='purpose', y='default_rate', palette='YlOrRd', ax=ax)
ax.set_title('Default Rate by Purpose')
ax.set_ylabel('Default Rate')
ax.set_xlabel('')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
X_eda.purpose.value_counts()
# Out:
# debt_consolidation    34606
# credit_card           13142
# home_improvement       3740
# other                  3407
# major_purchase         1292
# medical                 732
# small_business          703
# car                     583
# moving                  409
# vacation                392
# house                   358
# wedding                  95
# renewable_energy         26
# educational               9
# Name: purpose, dtype: int64

# %% [markdown]
# #### Default Rate by Purpose
# Loan purpose shows moderate variation in default rates across categories. Small business loans carry the highest default rate at approximately 27%, suggesting higher inherent risk in business financing. Moving and renewable energy loans follow closely. At the lower end, wedding and car loans default least frequently at around 13–15%, likely reflecting more predictable, one-time expenditures. Debt consolidation, the most common purpose in the dataset sits near the middle at approximately 21%, indicating it carries average risk despite its high volume.

# %%
# 4. Correlation heatmap (numeric only)
num_features = ['loan_amnt','int_rate','installment','annual_inc','dti',
                'open_acc','total_acc','inq_last_6mths','revol_util',
                'revol_bal','grade_numeric','loan_status']

corr = X_eda[num_features].corr()
fig, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm',
            center=0, ax=ax, linewidths=0.5, annot_kws={'size': 8})
ax.set_title('Feature Correlation Matrix')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Feature Correlation Matrix**
#
# Three notable findings stand out:
#
# **High multicollinearity:**
# - `loan_amnt` and `installment` are almost perfectly correlated at 0.95, this is expected since installment is mathematically derived from loan amount, term, and interest rate. Retaining both in a model introduces redundancy.
# - `int_rate` and `grade_numeric` correlate at 0.95, again expected, since grade directly determines the interest rate band assigned to a borrower. These two features carry nearly identical information.
# - `open_acc` and `total_acc` correlate at 0.70, moderate multicollinearity, less severe but worth noting.
#
# **Correlation with target (`loan_status`):**
# - `int_rate` and `grade_numeric` show the strongest correlation with default (0.26), consistent with the grade and distribution plots above.
# - Most other features show weak individual correlations with the target (below 0.15), confirming that default prediction requires feature combinations rather than single variables.
#
# **Low correlations elsewhere:**
# - The majority of feature pairs show correlations below 0.25, indicating the feature set is reasonably independent overall.
#
# **Implication:** The `loan_amnt`/`installment` and `int_rate`/`grade_numeric` pairs represent potential redundancy. In feature selection, retaining both from each pair adds noise without adding information — one from each pair is sufficient.

# %%
# 5. Distribution of continuous features (KDE)
continuous = ['loan_amnt', 'int_rate', 'installment', 'annual_inc',
              'dti', 'revol_util', 'revol_bal', 'open_acc', 'total_acc']

fig, axes = plt.subplots(3, 3, figsize=(15, 10))
axes = axes.flatten()

for i, col in enumerate(continuous):
    clipped = X_eda[[col, 'loan_status']].copy()
    clipped[col] = clipped[col].clip(upper=X_eda[col].quantile(0.99))
    sns.kdeplot(data=clipped, x=col, hue='loan_status',
                palette={0: '#00e07a', 1: '#ff4d4d'},
                linewidth=2, ax=axes[i], fill=True, alpha=0.15)
    axes[i].set_title(col)
    axes[i].set_ylabel('')
    legend = axes[i].get_legend()
    if legend:
        legend.set_title('')
        for t, label in zip(legend.texts, ['Fully Paid', 'Charged Off']):
            t.set_text(label)

plt.suptitle('Continuous Feature Distributions by Loan Status', y=1.01)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Continuous Feature Distributions by Loan Status (KDE)**
#
# **loan_amnt**: Both classes share a multimodal distribution peaking at common round-number amounts. The distributions are nearly identical in shape, confirming loan amount has limited standalone discriminative power.
#
# **int_rate**: The clearest separation across all nine features. Fully paid loans concentrate at lower rates (7–13%) while charged off loans spread more broadly toward higher rates. Interest rate is the strongest continuous predictor of default in this dataset.
#
# **installment**: Distributions mirror loan amount closely, which is expected given their 0.95 correlation. Both classes peak around $200–400 monthly with substantial overlap, limited additional information beyond loan amount.
#
# **annual_inc**: Both classes are right-skewed and heavily concentrated below $100k. Charged off borrowers skew slightly lower but the overlap is near-total, making income a weak standalone predictor.
#
# **dti**: Both classes follow a similar bell-shaped curve peaking around 15–20%. Charged off loans show a marginally heavier right tail at higher DTI values, but separation is minimal.
#
# **revol_util**: Broad, overlapping distributions across the full range for both classes. Revolving utilization shows very little separation, suggesting it carries limited predictive signal on its own.
#
# **revol_bal**: Both classes are heavily concentrated at lower balances with long right tails. The distributions are almost identical, indicating revolving balance is a weak discriminator.
#
# **open_acc**: Near-identical distributions peaking around 8–12 accounts. No meaningful separation between the classes.
#
# **total_acc**: Similar bell-shaped distributions for both classes with peaks around 20–25 accounts. Minimal class separation.
#
# **Takeaway:** Interest rate is the only continuous feature with a visually meaningful distributional difference between classes. Most features overlap heavily, reinforcing that a combination of features, including engineered ones is necessary for effective default prediction.

# %%
# 6. Boxplots for outlier visualization
fig, axes = plt.subplots(3, 3, figsize=(15, 10))
axes = axes.flatten()

for i, col in enumerate(continuous):
    clipped = X_eda[[col, 'loan_status']].copy()
    clipped[col] = clipped[col].clip(upper=X_eda[col].quantile(0.99))
    clipped['loan_status'] = clipped['loan_status'].map({0: 'Fully Paid', 1: 'Charged Off'})
    sns.boxplot(data=clipped, x='loan_status', y=col,
                palette={'Fully Paid': '#00e07a', 'Charged Off': '#ff4d4d'},
                linewidth=1.2, flierprops=dict(marker='o', markersize=2, alpha=0.3),
                ax=axes[i])
    axes[i].set_title(col)
    axes[i].set_xlabel('')
    axes[i].set_ylabel('')

plt.suptitle('Boxplots by Loan Status', y=1.01)
plt.tight_layout()
plt.show()

# %%
X_eda.describe()
# Out:
#           loan_amnt          term      int_rate   installment    annual_inc  \
# count  59494.000000  59494.000000  59494.000000  59494.000000  5.949400e+04
# mean   14398.486402     41.822301     13.301648    437.650741  7.634979e+04
# std     8736.254347     10.287751      4.792188    262.506449  8.417571e+04
# min     1000.000000     36.000000      5.310000     21.740000  0.000000e+00
# 25%     7925.000000     36.000000      9.750000    248.450000  4.546625e+04
# 50%    12000.000000     36.000000     12.790000    373.220000  6.500000e+04
# 75%    20000.000000     36.000000     16.020000    578.360000  9.000000e+04
# max    40000.000000     60.000000     30.990000   1714.540000  1.099920e+07
#
#          emp_length           dti      open_acc     total_acc  inq_last_6mths  \
# count  59494.000000  59494.000000  59494.000000  59494.000000    59494.000000
# mean       6.194238     18.289734     11.600682     24.973073        0.663075
# ...

# %% [markdown]
# **Boxplots by Loan Status**
#
# **loan_amnt**: Medians are nearly identical across both classes, with fully paid loans (~$12k), and Charged off loans (~$13k). Charged off loans show a slightly wider IQR, suggesting marginally more variance in default loan sizes, but the overlap is substantial.
#
# **int_rate**: The most pronounced separation of all nine features. The median interest rate for charged off loans (\~15%) is noticeably higher than for fully paid loans (\~12%), with the charged off IQR shifted entirely upward. This reinforces interest rate as the strongest individual predictor.
#
# **installment**: Mirrors loan amount closely given their high correlation. Medians are similar across classes with overlapping IQRs, There is limited discriminative value beyond what loan amount already captures.
#
# **annual_inc**: Both classes share nearly identical medians (~$65k) with heavily right-skewed distributions and numerous high-income outliers. This shows income alone does not separate defaulters from non-defaulters.
#
# **dti**: Charged off loans show a slightly higher median DTI and wider upper quartile, suggesting higher debt burden is associated with default risk. The separation is modest but consistent with expectations.
#
# **revol_util**: Medians differ marginally, with charged off borrowers showing slightly higher utilization. The IQRs overlap substantially, confirming weak standalone discriminative power.
#
# **revol_bal**: Both classes are heavily right-skewed with almost identical medians and extreme outliers extending far above the whiskers. Revolving balance shows no meaningful separation.
#
# **open_acc**: Near-identical distributions across both classes. Account count does not differentiate defaulters from non-defaulters.
#
# **total_acc**: Virtually identical boxplots for both classes, confirming total account history carries minimal predictive signal on its own.
#
# **Overall takeaway:** Interest rate is the only feature with a clear and consistent median shift between classes. All other features show substantial overlap, with dti offering a minor additional signal. This pattern is consistent across all visualization approaches applied so far.

# %%
# 7. IQR outlier counts per feature
print("=== OUTLIER ANALYSIS (IQR METHOD) ===\n")
outlier_summary = []
for col in continuous:
    q1 = X_eda[col].quantile(0.25)
    q3 = X_eda[col].quantile(0.75)
    iqr = q3 - q1
    lower = q1 - 1.5 * iqr
    upper = q3 + 1.5 * iqr
    n_outliers = ((X_eda[col] < lower) | (X_eda[col] > upper)).sum()
    pct = round(n_outliers / len(X_eda) * 100, 2)
    outlier_summary.append({'feature': col, 'lower_bound': round(lower, 2),
                            'upper_bound': round(upper, 2), 'outliers': n_outliers, 'pct': pct})

outlier_df = pd.DataFrame(outlier_summary).sort_values('pct', ascending=False)
outlier_df
# Out:
# === OUTLIER ANALYSIS (IQR METHOD) ===
#        feature  lower_bound  upper_bound  outliers   pct
# 6    revol_bal    -14683.62     40347.38      3481  5.85
# 3   annual_inc    -21334.38    156800.62      2892  4.86
# 7     open_acc        -1.00        23.00      2053  3.45
# 2  installment      -246.42      1073.22      1962  3.30
# 1     int_rate         0.35        25.42      1178  1.98
# 8    total_acc        -8.00        56.00       948  1.59
# 0    loan_amnt    -10187.50     38112.50       286  0.48
# 4          dti        -6.71        42.52       236  0.40
# 5   revol_util       -22.75       127.25         3  0.01

# %% [markdown]
# **Outlier Analysis (IQR Method)**
#
# `revol_bal` has the most severe outlier problem at 5.85% of records, revolving balances extend far beyond the upper bound of ~$40k, with some values reaching into the hundreds of thousands. This is a known characteristic of credit data where a small segment of borrowers carries disproportionately high balances.
#
# `annual_inc` follows at 4.87%, extreme income outliers are present, consistent with the long right tails observed in the KDE and boxplots. A small number of very high earners skew the distribution significantly.
#
# `open_acc` and `installment` both sit around 3.3–3.5%, indicating moderate outlier presence in account counts and monthly payment amounts respectively.
#
# `int_rate` at 1.99% is relatively clean, most rates fall within a predictable band given Lending Club's grading system, with outliers representing edge-case high-risk loans.
#
# `total_acc`, `loan_amnt`, `dti`, and `revol_util` all show low outlier rates below 2%, suggesting these features are reasonably bounded in this dataset.
#
# **Implication:** `revol_bal` and `annual_inc` require careful treatment before modelling, either capping at a percentile threshold or applying log transformation to reduce the influence of extreme values.

# %%
# 8. Default rate by home ownership
home_default = X_eda.groupby('home_ownership')['loan_status'].agg(['mean','count']).reset_index()
home_default.columns = ['home_ownership', 'default_rate', 'count']
home_default = home_default[home_default['count'] > 10].sort_values('default_rate', ascending=False)

fig, ax = plt.subplots(figsize=(8, 4))
sns.barplot(data=home_default, x='home_ownership', y='default_rate', palette='rocket', ax=ax)
ax.set_title('Default Rate by Home Ownership')
ax.set_ylabel('Default Rate')
ax.set_xlabel('')
for bar, val in zip(ax.patches, home_default['default_rate']):
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.003,
            f'{val:.1%}', ha='center', fontsize=9)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Default Rate by Home Ownership**
#
# Renters carry the highest default rate at 23.2%, followed by outright owners at 20.3% and mortgage holders at 17.8%. Borrowers classified as "ANY" show an unusually low rate of 7.7%, however this category represents only 13 records in the dataset and is therefore statistically unreliable.
#
# The pattern between the three main categories is intuitive, mortgage holders demonstrate the lowest default rate among meaningful groups, likely reflecting greater financial stability and creditworthiness required to maintain a mortgage. The approximately 5 percentage point spread between renters and mortgage holders suggests home ownership status carries modest but consistent predictive signal worth retaining in the model.

# %%
# 9. Default rate by verification status
verif_default = X_eda.groupby('verification_status')['loan_status'].mean().sort_values(ascending=False).reset_index()
verif_default.columns = ['verification_status', 'default_rate']

fig, ax = plt.subplots(figsize=(7, 4))
sns.barplot(data=verif_default, x='verification_status', y='default_rate', palette='Oranges_r', ax=ax)
ax.set_title('Default Rate by Verification Status')
ax.set_ylabel('Default Rate')
ax.set_xlabel('')
ax.set_xticklabels(ax.get_xticklabels(), rotation=30, ha='right')
for bar, val in zip(ax.patches, verif_default['default_rate']):
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.003,
            f'{val:.1%}', ha='center', fontsize=9)
plt.tight_layout()
plt.show()

# %%
X_eda.verification_status.value_counts()
# Out:
# Source Verified    23168
# Verified           18387
# Not Verified       17939
# Name: verification_status, dtype: int64

# %% [markdown]
# **Default Rate by Verification Status**
#
# Counterintuitively, fully verified borrowers default at the highest rate (24.3%), followed by source verified (21.0%), with unverified borrowers defaulting least frequently at 15.0%. This appears to contradict the expectation that verification reduces risk.
#
# This pattern is a well-documented phenomenon in Lending Club data and reflects **selection bias**, lenders tend to require income verification specifically for higher-risk applicants. In other words, borrowers who are asked to verify their income are already flagged as higher risk, which is why the verified group defaults more. Verification was triggered by risk, not the other way around.
#
# **Note**: This finding has an important modelling implication: verification status should not be interpreted as a direct causal protective factor. The encoded `verification_strength` feature will capture this pattern, but the direction of the relationship in the model may be counterintuitive to stakeholders reviewing SHAP outputs.

# %%
# 10. Default rate by stable_employment
emp_default = X_eda.groupby('stable_employment')['loan_status'].mean().reset_index()
emp_default.columns = ['stable_employment', 'default_rate']
emp_default['stable_employment'] = emp_default['stable_employment'].map({0: 'Unstable (<2yr)', 1: 'Stable (2yr+)'})

fig, ax = plt.subplots(figsize=(6, 4))
sns.barplot(data=emp_default, x='stable_employment', y='default_rate', palette='Blues', ax=ax)
ax.set_title('Default Rate by Employment Stability')
ax.set_ylabel('Default Rate')
ax.set_xlabel('')
for bar, val in zip(ax.patches, emp_default['default_rate']):
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.003,
            f'{val:.1%}', ha='center', fontsize=9)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Default Rate by Employment Stability**
#
# The difference between unstable (21.0%) and stable (20.1%) employment is negligible, less than 1 percentage point. Employment stability as defined here (under 2 years vs 2 years or more) has virtually no discriminative power for predicting default in this dataset.
#
# This is a notable finding that challenges the common assumption that employment tenure is a meaningful credit risk indicator. It suggests that how long someone has been employed matters far less than other financial characteristics such as interest rate, grade, and debt burden. This feature may contribute minimal signal in modelling and could potentially be dropped without meaningful loss in predictive performance.

# %% [markdown]
# Remove installment, grade_numeric and stable_employment note: standardscaler may still be sensitive to extreme values (The StandardScaler used in preprocessing will be sensitive to these outliers since it is not robust to extreme values, which could distort feature scaling.)

# %%
drop_cols = [
    'verification_status', 'emp_length', 'grade', 'purpose',
    'debt_to_income_ratio', 'high_risk_purpose', 'very_stable_employment',
    'strong_verification', 'high_risk_grade',
    'inquiry_pressure', 'high_utilization', 'installment', 'grade_numeric', 'stable_employment', 'revol_util', 'revol_bal'
]

X = X.drop(columns=drop_cols)



print(X.shape)
print(X.columns.tolist())
# Out:
# (59494, 19)
# ['loan_amnt', 'term', 'int_rate', 'annual_inc', 'home_ownership', 'dti', 'open_acc', 'total_acc', 'inq_last_6mths', 'delinq_2yrs', 'pub_rec', 'high_dti_flag', 'loan_to_monthly_income', 'very_high_utilization', 'large_loan_flag', 'long_term_loan', 'account_diversity', 'verification_strength', 'purpose_risk_score']

# %% [markdown]
# 'high_utilization', 'installment', 'grade_numeric', 'stable_employment'

# %%
y.shape
# Out:
# (59494,)

# %% [markdown]
# ### FEATURE SELECTION

# %%
# USING MUTUAL INFORMATION SCORE

# %%
# check which columns have inf
X_mi = X.copy()
print(X_mi.isin([np.inf, -np.inf]).sum())
# Out:
# loan_amnt                  0
# term                       0
# int_rate                   0
# annual_inc                 0
# home_ownership             0
# dti                        0
# open_acc                   0
# total_acc                  0
# inq_last_6mths             0
# delinq_2yrs                0
# pub_rec                    0
# high_dti_flag              0
# loan_to_monthly_income    20
# very_high_utilization      0
# large_loan_flag            0
# long_term_loan             0
# account_diversity          0
# verification_strength      0
# purpose_risk_score         0
# dtype: int64

# %%
X_mi['home_ownership'] = OrdinalEncoder().fit_transform(X_mi[['home_ownership']])
X_mi = X_mi.replace([np.inf, -np.inf], np.nan)
X_mi = X_mi.fillna(X_mi.median())

mi_scores = mutual_info_classif(X_mi, y, random_state=42)

mi_df = pd.DataFrame({
    'feature': X_mi.columns.tolist(),
    'mi_score': mi_scores
}).sort_values('mi_score', ascending=False)

print(mi_df.to_string(index=False))
print(X.shape)
# Out:
#                feature  mi_score
#               int_rate  0.038787
#                   term  0.020518
#         long_term_loan  0.013703
# loan_to_monthly_income  0.012701
#                    dti  0.009039
#     purpose_risk_score  0.007511
#         home_ownership  0.006752
#              loan_amnt  0.006306
#  verification_strength  0.005609
#             annual_inc  0.003249
#          high_dti_flag  0.003036
#                pub_rec  0.001741
#  very_high_utilization  0.001629
#            delinq_2yrs  0.001345
#      account_diversity  0.001163
#        large_loan_flag  0.000775
#         inq_last_6mths  0.000724
#              total_acc  0.000000
#               open_acc  0.000000
# (59494, 19)

# %%
drop_low_mi = [
    'large_loan_flag', 'total_acc', 'pub_rec',
    'account_diversity', 'open_acc', 'high_dti_flag', 'annual_inc'
]

X = X.drop(columns=drop_low_mi)
print(X.shape)
print(X.columns.tolist())
# Out:
# (59494, 12)
# ['loan_amnt', 'term', 'int_rate', 'home_ownership', 'dti', 'inq_last_6mths', 'delinq_2yrs', 'loan_to_monthly_income', 'very_high_utilization', 'long_term_loan', 'verification_strength', 'purpose_risk_score']

# %%
final_columns = ['loan_amnt', 'term', 'int_rate', 'home_ownership', 'dti', 'inq_last_6mths',
                 'delinq_2yrs', 'loan_to_monthly_income', 'very_high_utilization',
                 'long_term_loan', 'verification_strength', 'purpose_risk_score', 'loan_status']

# %%
lending_df = df[final_columns]

# %%
numeric_features = [c for c in final_columns if c not in ['home_ownership', 'loan_status']]
categorical_features = ['home_ownership']

print(X.shape)
print(X.columns.tolist())
# Out:
# (59494, 12)
# ['loan_amnt', 'term', 'int_rate', 'home_ownership', 'dti', 'inq_last_6mths', 'delinq_2yrs', 'loan_to_monthly_income', 'very_high_utilization', 'long_term_loan', 'verification_strength', 'purpose_risk_score']

# %%
X.shape, y.shape
# Out:
# ((59494, 12), (59494,))

# %%
# TRAIN-TEST SPLIT

X = X.replace([np.inf, -np.inf], np.nan)
X = X.fillna(X.median(numeric_only=True))

print(X.isin([np.inf, -np.inf]).sum().sum())
print(X.isnull().sum().sum())

test_size=0.2
val_size=0.15
random_state=42

# Train/val/test split

X_temp, X_test, y_temp, y_test = train_test_split(X, y, test_size=test_size, random_state=random_state, stratify=y)

val_ratio = val_size / (1 - test_size)
X_train, X_val, y_train, y_val = train_test_split(X_temp, y_temp, test_size=val_ratio, random_state=random_state, stratify=y_temp)
# Out:
# 0
# 0
# Saved.

# %%
# PREPROCESSING
numeric_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

categorical_transformer = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('ordinal', OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1))
])

preprocessor = ColumnTransformer([
    ('num', numeric_transformer, numeric_features),
    ('cat', categorical_transformer, categorical_features)
])

# Fit preprocessor
X_train_processed = preprocessor.fit_transform(X_train)
X_val_processed = preprocessor.transform(X_val)
X_test_processed = preprocessor.transform(X_test)


# Save preprocessor
joblib.dump(preprocessor, 'preprocessor.pkl')
print("Saved.")

# %%
background = X_val_processed
joblib.dump(background, "background.pkl")
# Out:
# ['background.pkl']

# %%
X_train_processed.shape, X_val_processed.shape, X_test_processed.shape
# Out:
# ((38670, 12), (8925, 12), (11899, 12))

# %%
# HANDLING TARGET IMBALANCE WITH SMOTE
smote = SMOTE(random_state=42)
X_train, y_train_bal = smote.fit_resample(X_train_processed, y_train)

print("Before SMOTE:", Counter(y_train))
print(f"After SMOTE: ", Counter(y_train_bal))
# Out:
# Before SMOTE: Counter({0: 30848, 1: 7822})
# After SMOTE:  Counter({0: 30848, 1: 30848})

# %%
# SAVING FEATURES
feature_names = numeric_features + categorical_features


joblib.dump(feature_names, 'feature_names.pkl')
print("Saved.")
print(feature_names)
# Out:
# Saved.
# ['loan_amnt', 'term', 'int_rate', 'dti', 'inq_last_6mths', 'delinq_2yrs', 'loan_to_monthly_income', 'very_high_utilization', 'long_term_loan', 'verification_strength', 'purpose_risk_score', 'home_ownership']

# %%
print(preprocessor.feature_names_in_)
# Out:
# ['loan_amnt' 'term' 'int_rate' 'home_ownership' 'dti' 'inq_last_6mths'
#  'delinq_2yrs' 'loan_to_monthly_income' 'very_high_utilization'
#  'long_term_loan' 'verification_strength' 'purpose_risk_score']

# %%
X_train.shape, y_train_bal.shape, X_test_processed.shape,  y_test.shape, X_val_processed.shape, y_val.shape
# Out:
# ((61696, 12), (61696,), (11899, 12), (11899,), (8925, 12), (8925,))

# %% [markdown]
# ### MODEL SELECTION, TRAINING, AND EVALUATION

# %%
# MODEL SELECTION, TRAINING, AND EVALUATION
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "Random Forest": RandomForestClassifier(random_state=42),
    "Decision Tree": DecisionTreeClassifier(random_state=42),
    "Naive Bayes": GaussianNB(),
    "Gradient Boosting": GradientBoostingClassifier(random_state=42),
    "XGBoost": XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)
}

# Evaluation function
def evaluate_models(models, X_train, y_train, X_val, y_val):
    results = []

    for name, model in models.items():
        model.fit(X_train, y_train)

        y_pred_1 = model.predict(X_val)
        y_proba_1 = model.predict_proba(X_val)[:,1] if hasattr(model, "predict_proba") else None

        acc = accuracy_score(y_val, y_pred_1)
        prec = precision_score(y_val, y_pred_1, zero_division=0)
        rec = recall_score(y_val, y_pred_1, zero_division=0)
        f1 = f1_score(y_val, y_pred_1, zero_division=0)
        roc_auc = roc_auc_score(y_val, y_proba_1) if y_proba_1 is not None else None

        results.append({
            "Model": name,
            "Accuracy": acc,
            "Precision": prec,
            "Recall": rec,
            "F1": f1,
            "ROC_AUC": roc_auc
        })

    return pd.DataFrame(results).sort_values(by="F1", ascending=False)

results_df = evaluate_models(models, X_train, y_train_bal, X_val_processed, y_val)

# %%
results_df
# Out:
#                  Model  Accuracy  Precision    Recall        F1   ROC_AUC
# 0  Logistic Regression  0.668908   0.333526  0.638227  0.438106  0.716256
# 3          Naive Bayes  0.679216   0.329904  0.568421  0.417497  0.699444
# 4    Gradient Boosting  0.674958   0.326911  0.573407  0.416415  0.700214
# 1        Random Forest  0.734790   0.346616  0.351801  0.349189  0.673406
# 5              XGBoost  0.722129   0.330996  0.366205  0.347712  0.651805
# 2        Decision Tree  0.669244   0.264863  0.357895  0.304430  0.553034

# %%
# Function to plot confusion matrices for already trained models
def plot_confusion_matrices(models, X_val, y_val):
    for name, model in models.items():
        y_pred = model.predict(X_val)
        cm = confusion_matrix(y_val, y_pred)

        disp = ConfusionMatrixDisplay(confusion_matrix=cm)
        disp.plot(cmap="Blues", values_format="d")
        plt.title(f"Confusion Matrix - {name}")
        plt.show()

plot_confusion_matrices(models, X_val_processed, y_val)

# %% [markdown]
# Logistic Regression performed better compared to other models trained, we are going to apply hyperparameter tuning and cross-validation to tune it to get better evaluation metrics.

# %%
# Defining the base model

log_reg = LogisticRegression(max_iter=5000, solver="liblinear")

# hyperparameter grid
param_grid = {
    "penalty": ["l1", "l2", "elasticnet", None],
    "C": [0.1, 1, 10, 100]
}

# StratifiedKFold to ensure class balance is preserved in splits
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# GridSearch with cross-validation
grid_search = GridSearchCV(
    estimator=log_reg,
    param_grid=param_grid,
    scoring="roc_auc",
    cv=cv,
    verbose=2,
    n_jobs=-1
)

grid_search.fit(X_train, y_train_bal)

print("Best Hyperparameters:", grid_search.best_params_)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# Best Hyperparameters: {'C': 0.1, 'penalty': 'l1'}

# %%
# Evaluate on validation set
y_val_pred = grid_search.predict(X_val_processed)
y_val_prob_1 = grid_search.predict_proba(X_val_processed)[:, 1]

print("\nValidation Results:")
print(classification_report(y_val, y_val_pred))
print("Validation ROC-AUC:", roc_auc_score(y_val, y_val_prob_1))
print(confusion_matrix(y_val, y_val_pred))
# Out:
# Validation Results:
#               precision    recall  f1-score   support
#
#            0       0.88      0.68      0.77      7120
#            1       0.33      0.64      0.44      1805
#
#     accuracy                           0.67      8925
#    macro avg       0.61      0.66      0.60      8925
# weighted avg       0.77      0.67      0.70      8925
#
# Validation ROC-AUC: 0.7162253727162377
# [[4815 2305]
#  [ 653 1152]]

# %%
# Final evaluation on test set
y_test_pred = grid_search.predict(X_test_processed)
y_test_prob = grid_search.predict_proba(X_test_processed)[:, 1]

print("\nTest Results:")
print(classification_report(y_test, y_test_pred))
print("Test ROC-AUC:", roc_auc_score(y_test, y_test_prob))
print(confusion_matrix(y_test, y_test_pred))
# Out:
# Test Results:
#               precision    recall  f1-score   support
#
#            0       0.88      0.67      0.76      9492
#            1       0.33      0.63      0.43      2407
#
#     accuracy                           0.66     11899
#    macro avg       0.60      0.65      0.59     11899
# weighted avg       0.77      0.66      0.69     11899
#
# Test ROC-AUC: 0.6988699818673972
# [[6362 3130]
#  [ 895 1512]]

# %%
# Saving the best model
joblib.dump(grid_search, 'model.pkl')
# Out:
# ['model.pkl']

# %%
# Loading the best model
model = joblib.load("model.pkl")

# %%
model
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=LogisticRegression(max_iter=5000, solver='liblinear'),
#              n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 100],
#                          'penalty': ['l1', 'l2', 'elasticnet', None]},
#              scoring='roc_auc', verbose=2)

# %%
print("Best parameters:", model.best_params_)
print("Best estimator:", model.best_estimator_)

# making predictions with loaded model
y_pred = model.predict(X_test_processed)
y_prob = grid_search.predict_proba(X_test_processed)[:, 1]
# Out:
# Best parameters: {'C': 0.1, 'penalty': 'l1'}
# Best estimator: LogisticRegression(C=0.1, max_iter=5000, penalty='l1', solver='liblinear')

# %%
print(classification_report(y_test, y_pred))
confusion_matrix(y_test, y_pred)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.67      0.76      9492
#            1       0.33      0.63      0.43      2407
#
#     accuracy                           0.66     11899
#    macro avg       0.60      0.65      0.59     11899
# weighted avg       0.77      0.66      0.69     11899
# array([[6362, 3130],
#        [ 895, 1512]], dtype=int64)

# %%
# Getting coefficients
best_model = grid_search.best_estimator_
coefficients = best_model.coef_[0]

coef_df = pd.DataFrame({
    "Feature": feature_names,
    "Coefficient": coefficients,
    "Abs_Coefficient": np.abs(coefficients)
})

# Sort by absolute coefficient
coef_df = coef_df.sort_values(by="Abs_Coefficient", ascending=False)

# %%
coef_df
# Out:
#                    Feature  Coefficient  Abs_Coefficient
# 2                 int_rate     0.514620         0.514620
# 8           long_term_loan     0.180814         0.180814
# 3                      dti     0.175952         0.175952
# 6   loan_to_monthly_income     0.160775         0.160775
# 11          home_ownership     0.084277         0.084277
# 9    verification_strength     0.045285         0.045285
# 0                loan_amnt    -0.043213         0.043213
# 4           inq_last_6mths     0.037655         0.037655
# 5              delinq_2yrs     0.023097         0.023097
# 1                     term     0.011708         0.011708
# 7    very_high_utilization    -0.008356         0.008356
# 10      purpose_risk_score    -0.000949         0.000949

# %%
plt.figure(figsize=(10,6))

sns.barplot(
    data=coef_df,
    x="Abs_Coefficient",
    y="Feature",
    palette="coolwarm"
)

plt.axvline(0, color="black", linestyle="--")
plt.title("Logistic Regression Feature Coefficients")
plt.show()

# %% [markdown]
# **Logistic Regression Feature Coefficients**
#
# `int_rate` dominates by a wide margin — its coefficient is roughly 3x the next feature, confirming it as the single strongest predictor of default in this model. Higher interest rates strongly increase default probability.
#
# `long_term_loan`, `dti`, and `loan_to_monthly_income` form a second tier — all pushing in the same direction, collectively capturing debt burden relative to income and loan structure.
#
# `home_ownership`, `verification_strength`, and `loan_amnt` contribute moderate signal.
#
# The bottom five — `inq_last_6mths`, `delinq_2yrs`, `term`, `very_high_utilization`, and `purpose_risk_score` — have near-zero coefficients, suggesting minimal independent contribution once the stronger features are accounted for. This is consistent with what EDA showed earlier.
#
# The model is essentially an interest rate and debt burden story. Everything else is noise reduction.

# %%
precision, recall, thresholds_pr = precision_recall_curve(y_test, y_prob)
average_precision = average_precision_score(y_test, y_prob)
plt.figure(figsize=(8,6))
plt.plot(recall, precision, color='green', label=f"Precision-Recall curve (AP = {average_precision:.2f})")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision-Recall Curve")
plt.legend(loc="lower left")
plt.show()

# %% [markdown]
# **Precision-Recall Curve (AP = 0.36)**
#
# AP of 0.36 against a random baseline of 0.20 (the class 1 proportion) means the model is performing meaningfully above chance — roughly 1.8x better than random on identifying defaults.
#
# The sharp drop at very low recall indicates the model is most precise when it's most conservative — it catches a small subset of defaults with high confidence, then precision degrades steadily as it tries to capture more.
#
# The jagged early section reflects the class imbalance — the model struggles to maintain consistent precision as recall increases past 0.1.
#
# The model is better at being selective than comprehensive. In a lending context that's acceptable — missing some defaults is less costly than wrongly rejecting good borrowers at scale. A threshold tuned toward higher precision would serve this use case better than the default 0.5 cutoff.
